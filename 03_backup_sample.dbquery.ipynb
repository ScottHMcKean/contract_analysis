-- %%
-- CONTRACT ANALYSIS
-- -- Backup and Sample

-- We want to material a backup of parsed using Delta (default format)
CREATE OR REPLACE TABLE IDENTIFIER(:catalog || '.' || :schema || '.parsed_backup') (
  SELECT * FROM IDENTIFIER(:catalog || '.' || :schema || '.parsed')
);

-- We also want a sample to iterate prompts
CREATE OR REPLACE TABLE IDENTIFIER(:catalog || '.' || :schema || '.parsed_sample') (
  SELECT * FROM IDENTIFIER(:catalog || '.' || :schema || '.parsed')
  ORDER BY path DESC
  LIMIT 100
)
